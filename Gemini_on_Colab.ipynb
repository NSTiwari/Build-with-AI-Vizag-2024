# %%
# !pip install -q -U google-generativeai

# %%
from google.colab import userdata
import google.generativeai as genai
from PIL import Image

# %%
API_KEY = userdata.get('gemini')

# Configure the API key.
genai.configure(api_key=API_KEY)

# %%
# List all available models.
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# #### Gemini Pro 1.0 (Text input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-pro')
prompt = "Suggest some best places to visit in Vizag."
# Give the input image and prompt, get response.

response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# **Beaches:**
#
# * **RK Beach:** A bustling beach with a promenade, rides, stalls, and a picturesque view of the Bay of Bengal.
# * **Visakhapatnam Beach:** A pristine beach with soft white sand and calm turquoise waters.
# * **Yarada Beach:** A secluded beach with rocky cliffs and a peaceful ambiance.
# * **Bheemili Beach:** A charming beach with a lighthouse, a fishing pier, and historical ruins.
#
# **Historical and Cultural Sites:**
#
# * **INS Kursura Submarine Museum:** Explore the interior of a retired submarine and learn about India's naval history.
# * **Dolphin's Nose:** A scenic viewpoint resembling a dolphin's head, offering panoramic views of the city and the coastline.
# * **Kailasagiri:** A hilltop park with beautiful gardens, a cable car, and a Lord Shiva temple.
# * **Simhachalam Temple:** A renowned Hindu temple dedicated to Lord Narasimha, known for its architectural grandeur.
#
# **Nature and Wildlife:**
#
# * **Bojjana Konda:** A picturesque hill with a Buddhist monastery and panoramic views of the city.
# * **Araku Valley:** A lush valley with waterfalls, coffee plantations, and tribal villages.
# * **Kambalakonda Wildlife Sanctuary:** Home to diverse wildlife, including elephants, tigers, and leopards.
# * **Mangamaripeta Beach:** A popular surfing spot with a serene ambiance.
#
# **Other Attractions:**
#
# * **Visakha Museum:** Showcases the rich history and culture of Visakhapatnam.
# * **Thotlakonda Buddhist Complex:** An ancient Buddhist monastery with preserved stupas and caves.
# * **Vuda Park:** A family-friendly park with amusement rides, water sports, and a lake.
# * **Insights Science City:** An interactive science museum with exhibits on various scientific topics.

# %%
print(response.candidates[0].safety_ratings)
# Out:
# [category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_HATE_SPEECH
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_HARASSMENT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: NEGLIGIBLE
# ]

# %% [markdown]
# #### Gemini Pro Vision 1.0 (Text + image input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-pro-vision')

# Load the image.
img = Image.open('/content/image01.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1075x768>

# %%
prompt = "Identify the place from the image."

# Give the input image and prompt, get response.
response = model.generate_content([prompt, img], stream=True)
response.resolve()

print(response.text)
# Out:
#  This is the famous Simhachalam temple located in the city of Visakhapatnam, Andhra Pradesh, India.
